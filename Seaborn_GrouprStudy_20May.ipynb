# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Jointplot

# %%
sns.jointplot(x= "math score", y="reading score", data=df);  # kind= default scatter

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="kde");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="kde", shade=True);

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="hex");  # Bu daha çok tercih ediliyor

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="hex", height=8, space=0.1, ratio=5);

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="hex", height=10, space=0.1, ratio=2);

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="reg");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="reg", ci=95);

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="kde", shade=True, hue="gender");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="kde", hue="gender");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="kde", shade=True, alpha=0.5, hue="gender");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="hist");

# %%
sns.jointplot(x= "math score", y="reading score", data=df, kind="hist", hue="gender", bins=50);

# %%
g= sns.jointplot(x= "math score", y="reading score", data=df)

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g= sns.jointplot(x= "math score", y="reading score", data=df)
g.plot_joint(sns.kdeplot, color="r", levels=10);

# %% [markdown]
# ## Styling

# %%
sns.jointplot(x= "math score", y="reading score", data=df, color="green")

# %%
sns.jointplot(x= "math score", y="reading score", data=df, hue="gender", palette="viridis")

# %%
c kind="hex",
              height=5,  # 6
              space=0.1,  # 0.2
              ratio=5);  # 5

# %%
sns.jointplot(x= "math score", y="reading score", data=df,
              joint_kws={"marker": 10})

# %%
sns.jointplot(x= "math score", y="reading score", data=df,
              kind="reg",
              joint_kws={"marker": 10, "ci":95, "order":2})

# %%
sns.jointplot(x= "math score", y="reading score", data=df,
              marginal_kws={"color":"green", "bins":30, "fill":None, "lw":4})

# %%
sns.jointplot(x= "math score", y="reading score", data=df,
              kind="kde",
              marginal_kws={"color":"g", "shade":True, "lw":4});

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df);

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.pairplot(df[["math score","reading score"]]);

# %%
sns.pairplot(df, hue="gender");

# %%
sns.pairplot(df, hue="gender", palette="viridis");

# %%
sns.pairplot(df, hue="gender", palette="viridis", corner=True);  # Tekrar edenleri almaz

# %%
sns.set_style("darkgrid")
sns.pairplot(df);

# %%
sns.pairplot(df, plot_kws={"color":"r"});

# %%
sns.pairplot(df, kind="kde", plot_kws={"color":"r"});

# %%
sns.pairplot(df, kind="kde", diag_kws={"color":"r"});

# %%
sns.pairplot(df, kind="kde", diag_kws={"color":"r"}, plot_kws={"color":"g"});

# %%
sns.pairplot(df, kind="reg", diag_kws={"color":"r"}, plot_kws={"color":"g"});

# %%
sns.pairplot(df, kind="reg", diag_kws={"color":"r"}, plot_kws={"color":"g"})
plt.tight_layout(pad=2);

# %%
sns.pairplot(df, kind="reg",
             plot_kws={"color":"r",
                      "scatter_kws": {"color":"grey"}}
             )
plt.tight_layout(pad=2);

# %%
from ipywidgets import interactive
def size_widget(height=2.5, aspect=1):
    sns.pairplot(data=df, height=height, aspect=aspect);

interactive(size_widget, height=(1,3.5,.5), aspect=(.5,2,0.25))
# Out:
# interactive(children=(FloatSlider(value=2.5, description='height', max=3.5, min=1.0, step=0.5), FloatSlider(va…

# %%
sns.pairplot(df, hue="gender");

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
sns.pairplot(df, hue="gender", vars=["reading score","writing score"]);

# %%
sns.pairplot(df, hue="gender",
             y_vars=["math score"],
             x_vars=["reading score","writing score"]);

# %%
sns.pairplot(df, hue="gender", kind="reg", height= 5,
             y_vars=["math score"],
             x_vars=["reading score","writing score"]);

# %% [markdown]
# # Catplot
#
# for categorical variables

# %%
sns.catplot(x="gender", y="math score", data=df, kind="box");

# %%
sns.catplot(x="gender", y="math score", data=df, kind="box", hue="lunch");

# %%
sns.catplot(x="gender", y="math score", data=df, kind="box", hue="lunch");

# %%
sns.catplot(x="gender", y="math score", row="lunch", data=df, kind="box", hue="lunch");

# %%
sns.catplot(x="gender", y="math score", col="lunch", data=df, kind="box", hue="lunch");

# %%
sns.catplot(x="lunch", y="math score", data=df, kind="box", hue="gender");

# %%
sns.catplot(x="gender", y="math score", row= "lunch", col="test preparation course", data=df, kind="box");

# %% [markdown]
# ## FacetGrid

# %%
sns.FacetGrid(data=df, col="gender", row="lunch");

# %%
g=sns.FacetGrid(data=df,col="gender",row="lunch")
#g = sns.FacetGrid(data=df,col=‘gender’,row=‘lunch’)
g = g.map(plt.scatter, "math score", "reading score", edgecolor="w")
g.add_legend()

# %%
g=sns.FacetGrid(data=df,col="gender",row="lunch")
#g = sns.FacetGrid(data=df,col=‘gender’,row=‘lunch’)
g = g.map(plt.scatter, "math score", "reading score", edgecolor="w")
g.add_legend()

plt.subplots_adjust(hspace=0.4, wspace=0.4)

# %%
g=sns.FacetGrid(data=df,col="gender",row="lunch")
#g = sns.FacetGrid(data=df,col=‘gender’,row=‘lunch’)
g = g.map(plt.scatter, "math score", "reading score", edgecolor="w")
g.add_legend()

plt.subplots_adjust(hspace=0.4, wspace=0.4)

# %% [markdown]
# # Heatmap

# %%
df=pd.read_csv("country_table.csv")

# %%
df.head()
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
